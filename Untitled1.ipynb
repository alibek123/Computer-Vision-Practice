# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img=cv2.imread('aaa.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
edges=cv2.Canny(img,0,200)
plt.imshow(edges,cmap='gray')
cv2.imwrite('C:/Users/zhuma/Desktop/edges.jpg', edges)
# Out:
# True
